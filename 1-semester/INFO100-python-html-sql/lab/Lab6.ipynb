# %% [markdown]
# # Oppgave 1
# Listeoperasjoner (lett)
#
# Lag en liste med navnene på dine fem favorittfrukter. Skriv deretter kode for følgende operasjoner:
# 1. Skriv ut hele listen med favorittfrukter.
# 2. Legg til en ny frukt i listen.
# 3. Fjern den andre frukten i listen.
# 4. Finn lengden (antall elementer) i listen.
# 5. Sjekk om "banan" er i listen.

# %%
fav_fruits = ['apple', 'pear', 'peach', 'dragonfruit', 'avokado']

#1.
print("1. \n")
print(fav_fruits)

#2. 
print("2. \n")
fav_fruits.append('grape')
print (fav_fruits)

#3. 
print("3. \n")
fav_fruits.pop(1)
print(fav_fruits)

#4. 
print("4. \n")
len(fav_fruits)

#5. 
print("5. \n")
if 'banana'in fav_fruits:
    print("Ja, 'banana' er i denne listen.")
else:
    print("Nei, 'banana' er ikke i denne listen.")
# Out:
# 1.
#
# ['apple', 'pear', 'peach', 'dragonfruit', 'avokado']
# 2.
#
# ['apple', 'pear', 'peach', 'dragonfruit', 'avokado', 'grape']
# 3.
#
# ['apple', 'peach', 'dragonfruit', 'avokado', 'grape']
# 4.
#
# 5.
#
# Nei, 'banana' er ikke i denne listen.

# %% [markdown]
# # Oppgave 2
# Oppgave 2. Klasser og objekter (middels)
#
# Utvid Python-klassen kalt Student som har følgende attributter:
#
#     navn
#     alder
#     studieretning
#
# Legg til følgende metoder i klassen:
#
#     def skriv_navn(self): En metode som skriver ut studentens navn med følgende setning: "Studenten heter {navn}".
#     def returner_alder(self): En metode som returnerer studentens alder.
#     def skriv_studieretning(self): En metode som skriver ut studentens studieretning med følgende setning: "{navn} studerer {retning}".

# %%
class Student:
    def __init__(self, name, age, study):
        self.name = name
        self.age = age
        self.study = study

    def write_name(self):
        print(f"The students name is {self.name}.")
    
    def return_age(self):
        return self.age
    
    def write_study(self):
        print(f"The students study is {self.study}.")

student1 = Student("Alice", 20, "Informatikk")
student2 = Student("Bob", 22, "Math")

student1.write_name()

print(student1.return_age())

student1.write_study()

student2.write_name()

print(student2.return_age())

student2.write_study()
# Out:
# The students name is Alice.
# 20
# The students study is Informatikk.
# The students name is Bob.
# 22
# The students study is Math.

# %% [markdown]
# # Oppgave 3
# Oppgave 3. Moduler og Import (middels)
#
# 3a)  Lag en Python-fil som heter geometri.py som inneholder funksjoner for å beregne området av en firkant og en sirkel.
#
# Eksempelkall og forventet utskrift:
#
#     areal_firkant(4,5)
#     20
#
#     areal_sirkel(5)
#     78.5
#
#
#
# 3b)  Importer denne filen som en modul i en annen fil kalt "beregn_areal.py" og bruk funksjonene til å beregne arealet av en firkant med bredde 5 og lengde 10, samt arealet av en sirkel med radius 3.

# %%
import geometry

print(geometry.areal_firkant(5, 10))
print(geometry.areal_sirkel(3))
# Out:
# 50
# 28.274333882308138

# %% [markdown]
# # Oppgave 4
# Oppgave 4. Nøstede objekter (vanskelig)
#
# 4a)  Lag en Python-klasse kalt Person som har følgende attributter:
#
#     navn
#     alder
#
# Person-klassen skal ikke ha noen metoder.
#
#
#
# 4b)  Lag en Python-klasse kalt Bil som har følgende attributter:
#
#     merke
#     modell
#     eier (et objekt fra Person-klassen fra 4a)
#
# Skriv også en metode i Bil-klassen som kan skrive ut eieren av bilen.
#
# Eksempelkall og forventet utskrift:
#
#     alice = Person("Alice", 30)
#     bob = Person("Bob", 25)
#     camry = Bil("Toyota", "Camry", alice)
#     focus = Bil("Ford", "Focus", bob)
#     camry.skriv_eier()
#     Alice eier bilen
#     focus.skriv_eier()
#     Bob eier bilen

# %%
class Person:
    def __init__(self, navn, alder):
        self.navn = navn
        self.alder = alder

class Bil:
    def __init__(self, merke, modell, eier):
        self.merke = merke
        self.modell = modell
        self.eier = eier

    def skriv_eier(self):
        print(f"{self.eier.navn} eier bilen")

# Eksempelkall
alice = Person("Alice", 30)
bob = Person("Bob", 25)
camry = Bil("Toyota", "Camry", alice)
focus = Bil("Ford", "Focus", bob)

camry.skriv_eier()  # Skriver ut: Alice eier bilen
focus.skriv_eier()  # Skriver ut: Bob eier bilen
# Out:
# Alice eier bilen
# Bob eier bilen
