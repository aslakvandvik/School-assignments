# %% [markdown]
# Task 1: In this assignment you will work with NetworkX library. The details are given
# below:
#
# You have to load a graph representing Zachary's Karate club using the following code:
#
# G = nx.karate_club_graph()
#
# This graph contains nodes representing member of the club and includes attributes named
# 'club' which represents which group the members belong after the seperation of the club.
# You will find either Mr. Hi, or Officer... it indicates two different groups.

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np

G = nx.karate_club_graph()

# %% [markdown]
# Task 1.1: Print out the list of nodes and edges with attributes.

# %%
# Print nodes with attributes
print("Nodes with attributes:")
print(list(G.nodes(data=True)))

# Print edges with attributes
print("\nEdges with attributes:")
print(list(G.edges(data=True)))
# Out:
# Nodes with attributes:
# [(0, {'club': 'Mr. Hi'}), (1, {'club': 'Mr. Hi'}), (2, {'club': 'Mr. Hi'}), (3, {'club': 'Mr. Hi'}), (4, {'club': 'Mr. Hi'}), (5, {'club': 'Mr. Hi'}), (6, {'club': 'Mr. Hi'}), (7, {'club': 'Mr. Hi'}), (8, {'club': 'Mr. Hi'}), (9, {'club': 'Officer'}), (10, {'club': 'Mr. Hi'}), (11, {'club': 'Mr. Hi'}), (12, {'club': 'Mr. Hi'}), (13, {'club': 'Mr. Hi'}), (14, {'club': 'Officer'}), (15, {'club': 'Officer'}), (16, {'club': 'Mr. Hi'}), (17, {'club': 'Mr. Hi'}), (18, {'club': 'Officer'}), (19, {'club': 'Mr. Hi'}), (20, {'club': 'Officer'}), (21, {'club': 'Mr. Hi'}), (22, {'club': 'Officer'}), (23, {'club': 'Officer'}), (24, {'club': 'Officer'}), (25, {'club': 'Officer'}), (26, {'club': 'Officer'}), (27, {'club': 'Officer'}), (28, {'club': 'Officer'}), (29, {'club': 'Officer'}), (30, {'club': 'Officer'}), (31, {'club': 'Officer'}), (32, {'club': 'Officer'}), (33, {'club': 'Officer'})]
#
# Edges with attributes:
# ...

# %% [markdown]
# Task 1.2: You have to provide a visualization of the Karate club where the color of nodes will
# represent the two groups after the seperation.

# %%
# Define color map based on 'club' attribute
color_map = ['orange' if G.nodes[node]['club'] == 'Mr. Hi' else 'lightblue' for node in G.nodes()]

plt.figure(figsize=(8, 6))
nx.draw(G, with_labels=True, node_color=color_map, node_size=500)
plt.title("Karate Club Division Visualization")
plt.show()

# %% [markdown]
# Task 1.3:  Using nx.dijkstra_path() find out the shortest path from node 24 to 16.  Print the list of
# nodes.

# %%
path = nx.dijkstra_path(G, source=24, target=16)
print("Shortest path from 24 to 16:", path)
# Out:
# Shortest path from 24 to 16: [24, 31, 0, 5, 16]

# %% [markdown]
# Task 1.4: You have to provide a visualization of the Karate club and modify the color of the nodes by highlighting the selected nodes from the above list.
# Use red color to indicate the selection of the nodes.

# %%
# Update color map: red for path nodes
path_set = set(path)
color_map_path = ['red' if node in path_set else 
                  'orange' if G.nodes[node]['club'] == 'Mr. Hi' else 'lightblue' 
                  for node in G.nodes()]

plt.figure(figsize=(8, 6))
nx.draw(G, with_labels=True, node_color=color_map_path, node_size=500)
plt.title("Karate Club with Shortest Path Highlighted")
plt.show()
