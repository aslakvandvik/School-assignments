# %%
# !pip install torchkge
# !pip install sklearn
# !git clone https://github.com/villmow/datasets_knowledge_embedding.git
# Out:
# Collecting torchkge
#   Downloading torchkge-0.17.7-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: torch>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from torchkge) (2.6.0)
# Requirement already satisfied: tqdm>=4.64 in /opt/anaconda3/lib/python3.12/site-packages (from torchkge) (4.66.5)
# Requirement already satisfied: pandas>=1.4 in /opt/anaconda3/lib/python3.12/site-packages (from torchkge) (2.2.2)
# Requirement already satisfied: numpy>=1.22 in /opt/anaconda3/lib/python3.12/site-packages (from torchkge) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.4->torchkge) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.4->torchkge) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.4->torchkge) (2023.3)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.2.0->torchkge) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.2.0->torchkge) (4.11.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.2.0->torchkge) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.2.0->torchkge) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.2.0->torchkge) (2024.6.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.2.0->torchkge) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.2.0->torchkge) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.2.0->torchkge) (1.3.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.4->torchkge) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.2.0->torchkge) (2.1.3)
# Downloading torchkge-0.17.7-py2.py3-none-any.whl (51 kB)
# Installing collected packages: torchkge
# Successfully installed torchkge-0.17.7
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Cloning into 'datasets_knowledge_embedding'...
# remote: Enumerating objects: 80, done.
# remote: Total 80 (delta 0), reused 0 (delta 0), pack-reused 80 (from 1)
# Receiving objects: 100% (80/80), 124.92 MiB | 6.82 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
from torchkge.utils.datasets import load_fb15k237

kg_train, kg_val, kg_test = load_fb15k237()

print(list(kg_train.ent2ix.keys())[-10:])
print(list(kg_train.rel2ix.keys())[-10:])


"""Download files with human-readable labels for (most) Freebase entities used in the dataset. 
Labels seem to be missing for some entities used in FB15k-237."""

import json

TEXT_TRIPLES_DIR = 'datasets_knowledge_embedding/FB15k-237/'
with open(TEXT_TRIPLES_DIR+'entity2wikidata.json') as file:
    _entity2wikidata = json.load(file)

 ent2lbl = {
    ent: wd['label']
    for ent, wd in _entity2wikidata.items()
}
lbl2ent = {lbl: ent for ent, lbl in ent2lbl.items()}

print([
    ent2lbl[ent] 
    for ent in kg_train.ent2ix.keys()
    if ent in ent2lbl][-10:])
# Out:
#   File <string>:18
#     ent2lbl = {
#                ^
# IndentationError: unindent does not match any outer indentation level
